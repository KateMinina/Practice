# %% [markdown]
# # Практическая работа №1

# %% [markdown]
# ## Задание 1

# %% [markdown]
# В первом задании я создала два файла, которые имеют референсные ссылки друг на друга. Структура файлов выглядит следующим образом:
#
# ```
# myproject/
# ├── about
# │   └── aboutme.html
# └── index.html
# ```
#
# ## 1. Файл index.html
#
# <!DOCTYPE HTML>
# <html>
# <head>
# 	<title>
# 		Index
# 	</title>
# </head>
# <body>
#
# <a href="C:/User/Admin/Desktop/WEB/myproject/about/aboutme.html">
# 	<H1>
# 		Абсолютная ссылка на файл aboutme.html
# 	</H1>
# </a>
#
# <a href="C:/User/Admin/Desktop/WEB/myproject/about/aboutme.html">
# 	<H1>
# 		Прямая ссылка на файл aboutme.html
# 	</H1>
# </a>
#
# </body>
# </html>

# %% [markdown]
# ## 2. Файл aboutme.html
#
# <!DOCTYPE html>
# <html>
# <head>
# 	<title>
# 		Aboutme
# 	</title>
# </head>
# <body>
#
# <a href="C:/User/Admin/Desktop/WEB/myproject/about/index.html">
# 	<H1>
# 		Абсолютная ссылка на файл Index.html
# 	</H1>
# </a>
#
# <a href="C:/User/Admin/Desktop/WEB/myproject/about/index.html">
# 	<H1>
# 		Прямая ссылка на файл Index.html
# 	</H1>
# </a>
#
# </body>
# </html>

# %% [markdown]
# ## Задание 2

# %% [markdown]
# Во втором задании я подключилась по telnet к http://adme.ru и отправила запрос:
# ```
# GET /wiki/страница HTTP/1.1
# Host: ru.wikipedia.org
# User-Agent: Mozilla/5.0 (X11; U; Linux i686; ru; rv:1.9b5) Gecko/2008050509 Firefox/3.0b5
# Accept: text/html
# Connection: close
# (пустая строка)
# ```
#
# Ответ:
# ```
# HTTP/1.1 301 Moved Permanently
# Date: Sat, 29 Sep 2018 05:31:40 GMT
# Content-Type: text/html
# Content-Length: 182
# Connection: close
# Location: https://www.adme.ru/adme/zhizn-dobro
# Server: nginx
# Set-Cookie: ug=RU;Path=/
# X-Request-Id: 8916777d9ff729d383a2cffa122ce240
#
# <html>
# <head><title>301 Moved Permanently</title></head>
# <body bgcolor="white">
# <center><h1>301 Moved Permanently</h1></center>
# <hr><center>openresty</center>
# </body>
# </html>
# ```
# Описание работы:
# Протокол HTTP версии 1.1. Код ответа - 301 Moved Permanently, перенаправлен и означает, что документ сменил URL. В заголовке Location указывается новый URL документа при перенаплавлении.

# %% [markdown]
# ## Задание 3

# %% [markdown]
# Отправить запросы на http://httpbin.org, проанализировать ответ и код состояния. Описать работу HTTP протокола в каждом запросе.
#
# ## /ip
# ```
# GET /ip HTTP/1.1
# Host: httpbin.org
# Accept: */*
# ```
# ## Ответ:
# ```
# HTTP/1.1 200 OK
# Connection: keep-alive
# Server: gunicorn/19.9.0
# Date: Sat, 29 Sep 2018 06:12:20 GMT
# Content-Type: application/json
# Content-Length: 32
# Access-Control-Allow-Origin: *
# Access-Control-Allow-Credentials: true
# Via: 1.1 vegur
#
# {
#    "origin": "212.193.94.40"
#                             }
# ```
# Протокол HTTP версии 1.1. Код состояния - 200 OK, запрос успешно выполнен.
#
# ## /get
# ```
# GET /get?foo=bar&1=2&2/0&error=True HTTP/1.1
# Host: httpbin.org
# Accept: */*
# ```
# ## Ответ:
# ```
# HTTP/1.1 200 OK
# Connection: keep-alive
# Server: gunicorn/19.9.0
# Date: Sat, 29 Sep 2018 06:18:20 GMT
# Content-Type: application/json
# Content-Length: 282
# Access-Control-Allow-Origin: *
# Access-Control-Allow-Credentials: true
# Via: 1.1 vegur
#
# {
#    "args": {
#                 "1": "2",
#                               "2/0": "",
#                                              "error": "True",
#                                                                   "foo": "bar"
#
# },
#      "headers": {
#                      "Accept": "*/*",
#                                           "Connection": "close",
#                                                                      "Host": "ht
# tpbin.org"
#             },
#                  "origin": "212.193.94.40",
#                                               "url": "http://httpbin.org/get?foo
# =bar&1=2&2%2F0&error=True"
#                           }
# ```
# Протокол HTTP версии 1.1. Код состояния - 200 OK, запрос успешно выполнен.
#
# ## /post
# ```
# POST /post HTTP/1.1
# Host: httpbin.org
# Accept: */*
# Content-Length: 29
# Content-Type: application/x-www-form-urlencoded
#
# foo=bar&1=2&2%2F0=&error=True
# ```
# ## Ответ:
# ```
# HTTP/1.1 200 OK
# Connection: keep-alive
# Server: gunicorn/19.9.0
# Date: Sat, 29 Sep 2018 06:33:06 GMT
# Content-Type: application/json
# Content-Length: 404
# Access-Control-Allow-Origin: *
# Access-Control-Allow-Credentials: true
# Via: 1.1 vegur
#
# {
#    "args": {},
#                  "data": "",
#                                "files": {},
#                                               "form": {
#                                                            "1": "2",
#                                                                          "2/0":
# "",
#         "error": "True",
#                              "foo": "bar"
#                                            },
#                                                 "headers": {
#                                                                 "Accept": "*/*",
#
#      "Connection": "close",
#                                 "Content-Length": "29",
#                                                             "Content-Type": "app
# lication/x-www-form-urlencoded",
#                                      "Host": "httpbin.org"
#                                                             },
#                                                                  "json": null,
#
#  "origin": "212.193.94.40",
#                               "url": "http://httpbin.org/post"
#                                                               }
# ```
# Статус: 200 ОК, запрос выполнен успешно.
#
# ## /cookies/set
# ```
# GET /cookies/set?country=Ru HTTP/1.1
# Host: httpbin.org
# Accept: */*
# ```
# ## Ответ:
# ```
# HTTP/1.1 302 FOUND
# Connection: keep-alive
# Server: gunicorn/19.9.0
# Date: Sat, 29 Sep 2018 06:25:20 GMT
# Content-Type: text/html; charset=utf-8
# Content-Length: 223
# Location: /cookies
# Set-Cookie: country=Ru; Path=/
# Access-Control-Allow-Origin: *
# Access-Control-Allow-Credentials: true
# Via: 1.1 vegur
#
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 3.2 Final//EN">
#                                                        <title>Redirecting...</ti
# tle>
#     <h1>Redirecting...</h1>
#                            <p>You should be redirected automatically to target U
# RL: <a href="/cookies">/cookies</a>.  If not click the link.
# ```
# Протокол HTTP версии 1.1. Код состояния - 302 FOUND, означает - повторить запрос по другому URL.
#
# ## /cookies
# ```
# GET /cookies HTTP/1.1
# Host: httpbin.org
# Accept: */*
# ```
# ## Ответ:
# ```
# HTTP/1.1 200 OK
# Connection: keep-alive
# Server: gunicorn/19.9.0
# Date: Sat, 29 Sep 2018 06:36:25 GMT
# Content-Type: application/json
# Content-Length: 20
# Access-Control-Allow-Origin: *
# Access-Control-Allow-Credentials: true
# Via: 1.1 vegur
#
# {
#    "cookies": {}
#                 }
# ```
# Статус: 200 OK.
#
# ## /redirect
# ```
# GET /redirect/4 HTTP/1.1
# Host: httpbin.org
# Accept: */*
# ```
# ## Ответ:
# ```
# HTTP/1.1 302 FOUND
# Connection: keep-alive
# Server: gunicorn/19.9.0
# Date: Sat, 29 Sep 2018 06:38:34 GMT
# Content-Type: text/html; charset=utf-8
# Content-Length: 247
# Location: /relative-redirect/3
# Access-Control-Allow-Origin: *
# Access-Control-Allow-Credentials: true
# Via: 1.1 vegur
#
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 3.2 Final//EN">
#                                                        <title>Redirecting...</ti
# tle>
#     <h1>Redirecting...</h1>
#                            <p>You should be redirected automatically to target U
# RL: <a href="/relative-redirect/3">/relative-redirect/3</a>.  If not click the l
# ink.
# ```
# Статус: 302 FOUND

# %% [markdown]
# ## Задание 4
# Создать HTML форму c action="http://httpbin.org/post" method="POST" и enctype="multipart/form-data"
# Добавить в форму поля firstname, lastname, group, message (textarea), myimg (file).
# Проверить результат отправки данных формы.
#
# ##
# ```
# <!DOCTYPE html>
#  <html>
#     <head>
#         <meta charset="utf-8">
#         <title>
#         </title>
#     </head>
#     <body>
#         <form action="http://httpbin.org/post" method="POST" enctype="multipart/form-data">
#             <p>
#             First name:
#             <input type="text" name="first name" size="10" maxlength="60">
#             </p>
#             <p>
#             Last name:
#             <input type="text" name="lastname" size="10" maxlength="60">
#             </p>
#             <p>
#             Group:
#             <input type="text" name="group" size="10" maxlength="60">
#             </p>
#             <p>
#             Message:
#             <input type="textarea" name="message" size="10" maxlength="60">
#             </p>
#             <p>
#             Myimg:
#             <input type="file" value="myimg" name="myimg" size="25" maxlength="150">
#             </p>
#             <input type="submit" value="submit">
#         </form>
#     </body>
# </html>
#
# Ответ:
# {
#   "args": {},
#   "data": "",
#   "files": {
#     "myimg":
#      },
#   "form": {
#     "first name": "\u041a\u0430\u0442\u044f",
#     "group": "\u041d\u041c\u0422-362701",
#     "lastname": "\u041c\u0438\u043d\u0438\u043d\u0430",
#     "message": ":)"
#   },
#   "headers": {
#     "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8",
#     "Accept-Encoding": "gzip, deflate",
#     "Accept-Language": "ru,en;q=0.9",
#     "Cache-Control": "max-age=0",
#     "Connection": "close",
#     "Content-Length": "1877778",
#     "Content-Type": "multipart/form-data; boundary=----WebKitFormBoundaryw7o3109LALWaJSnq",
#     "Host": "httpbin.org",
#     "Origin": "null",
#     "Upgrade-Insecure-Requests": "1",
#     "User-Agent": "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/68.0.3440.106 YaBrowser/18.9.1.954 Yowser/2.5 Safari/537.36"
#   },
#   "json": null,
#   "origin": "195.64.208.144",
#   "url": "http://httpbin.org/pos
#  ```
#
#  ## Ответ:
#  ```
#  {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "first name": "\u041a\u0430\u0442\u044f",
#     "group": "\u041d\u041c\u0422-362701",
#     "lastname": "\u041c\u0438\u043d\u0438\u043d\u0430",
#     "message": ":)",
#     "myimg": ""
#   },
#   "headers": {
#     "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8",
#     "Accept-Encoding": "gzip, deflate",
#     "Accept-Language": "ru,en;q=0.9",
#     "Cache-Control": "max-age=0",
#     "Connection": "close",
#     "Content-Length": "602",
#     "Content-Type": "multipart/form-data; boundary=----WebKitFormBoundaryeV9Iny5kpXVKohHN",
#     "Host": "httpbin.org",
#     "Origin": "null",
#     "Upgrade-Insecure-Requests": "1",
#     "User-Agent": "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/68.0.3440.106 YaBrowser/18.9.1.954 Yowser/2.5 Safari/537.36"
#   },
#   "json": null,
#   "origin": "195.64.208.144",
#   "url": "http://httpbin.org/post"
# }
# ```
